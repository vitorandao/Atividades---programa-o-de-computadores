# %% [markdown]
# <a href="https://colab.research.google.com/github/vitorandao/Atividades---programa-o-de-computadores/blob/main/Lista_de_Exerc%C3%ADcios_de_Programa%C3%A7%C3%A3o_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Bloco 1 — Utilize apenas: if (Exercícios 1 a 10)**

# %% [markdown]
# **1) Verificar maioridade.** Leia a idade de uma pessoa e exiba "Você é maior de idade." caso ela
# tenha 18 anos ou mais.

# %%
idade=int(input("digite sua idade:"))
if idade >=18:
    print("você é maior de idade")

# %% [markdown]
# **2) Número positivo.** Leia um número inteiro e exiba "O número é positivo." se ele for maior que
# zero.

# %%
num=int(input("digite um número"))
if num>=2==0:
    print("o número é par")

# %% [markdown]
# **3) Número par.** Leia um número inteiro e exiba "O número é par." se ele for divisível por 2.

# %%
num=int(input("digite"))
if num %2==0:
    print("o número é par")

# %% [markdown]
# **4) Detectar febre.** Leia a temperatura corporal (em °C) e exiba "Atenção: você está com febre!" se
# for superior a 37,5 °C.

# %%
temp=float(input("digite a temperatura corporal:"))
if temp>37.5:
    print("atenção: você está com febre!")

# %% [markdown]
# **5) Velocidade acima do limite.** Leia a velocidade de um veículo (km/h). Se ultrapassar 80 km/h,
# exiba "Velocidade acima do limite!".

# %%
vel=float(inpt("digite sua velocidade:"))
if vel>80:
  print("velocidade acima do limite")

# %% [markdown]
# **6) Aprovação por nota.** Leia a nota de um aluno (0 a 10). Se for maior ou igual a 7, exiba
# "Aprovado!".

# %%
nota=float(input("digite sua nota:"))
if nota>=7:
    print("aprovado")

# %% [markdown]
# **7) Maior entre dois números.** Leia dois números inteiros. Se o primeiro for maior que o segundo,
# exiba "O primeiro número é maior.".

# %%
a=int(input("digite um número:"))
b=int(input("digite outro número:"))
if a>b:
    print("o primeiro número é par")

# %% [markdown]
# **8) Divisível por 5.** Leia um número inteiro e exiba "Divisível por 5." se a condição for verdadeira.

# %%
num-int(input("digite um número:"))
if num%5==0:
    print("divisivel por 5")

# %% [markdown]
# **9) Salário acima do mínimo.** Leia o salário de um funcionário. Se for superior a R$ 1.412,00, exiba
# "Salário acima do mínimo vigente.".

# %%
salario=float(input("digite seu salário:"))
if salario>1412:
    print("salário acima do mínimo vigente")

# %% [markdown]
# **10) Ano bissexto (simplificado).** Leia um ano e exiba "Ano bissexto!" se ele for divisível por 4 e (não
# divisível por 100 ou divisível por 400)

# %%
ano=int(input("digite um ano:"))
if ano%4==0 and (ano%100!=0 or ano%400==0):
  print("ano bissexto")
